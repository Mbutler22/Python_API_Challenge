# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Read the cities.csv to create a DataFrame
#.. for another file

cities= pd.read_csv("../output_data/cities.csv")
cities.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
#2 square brackets to look at 2 columns Set variable

marker_locations=cities[["Lat","Lng"]]

#Find the humidity

weight=cities["Humidity"]

# %%
#add the heatmap

fig= gmaps.figure()
heat_layer=gmaps.heatmap_layer(marker_locations, 
                               weights=weight,
                              dissipating=False,
                              max_intensity=300,
                              point_radius= 10)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# Narrow down the DataFrame to find your ideal weather condition. For example:
#
# A max temperature lower than 80 degrees but higher than 70.
#
# Wind speed less than 10 mph.
#
# Zero cloudiness.
#
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

# %%
#Filter max temp <80 but higher than 70
#cities.loc[(cities["Max Temp"]<80) & (cities["Max Temp"]>70)\
    # &(cities["Wind Speed"]<10) &


new_df = cities[(cities['Max Temp'] >=75) & cities['Max Temp'] <=90]
new_df = new_df[new_df['Wind Speed'] <= 10]
new_df = new_df[new_df['Cloudiness'] <= 10]
new_df = new_df[new_df['Humidity']<=70]
new_df =new_df
new_df
# Out:
#      City_ID               City  Cloudiness Country        Date  Humidity  \
# 3          3             zhuhai           0      CN  1558378755        39
# 7          7              opuwo           0     NaN  1558378523        23
# 9          9  pushkinskiye gory           6      RU  1558378756        70
# 11        11             castro           0      CL  1558378756        70
# 26        26        colonelganj           0      IN  1558378759        14
# 30        30            gobabis           0     NaN  1558378567        24
# 31        31            qingdao           0      CN  1558378760        54
# 33        33              arman           0      RU  1558378760        64
# 37        37            varhaug           0      NO  1558378761        63
# 50        50             kodiak           1      US  1558378763        63
# 70        70       ponta do sol           0      BR  1558378767        57
# 88        88           cidreira           0      BR  1558378770        66
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Create a hotel_df from new_df

hotel_df = new_df.loc[:,["City", "Country", "Lat", "Lng"]]
hotel_df["Hotel Name"]=""

hotel_df
# Out:
#                   City Country    Lat     Lng Hotel Name
# 3               zhuhai      CN  40.71  112.04
# 7                opuwo     NaN -18.06   13.84
# 9    pushkinskiye gory      RU  57.02   28.91
# 11              castro      CL -42.48  -73.76
# 26         colonelganj      IN  27.13   81.70
# 30             gobabis     NaN -22.45   18.97
# 31             qingdao      CN  36.09  120.35
# 33               arman      RU  59.70  150.17
# 37             varhaug      NO  58.61    5.65
# 50              kodiak      US  39.95  -94.76
# 70        ponta do sol      BR -20.63  -46.00
# 88            cidreira      BR -30.17  -50.22
# 112         bredasdorp      ZA -34.53   20.04
# 138          morondava      MG -20.30   44.28
# 142          sarai mir      IN  26.02   82.92
# 149            ganzhou      CN  25.86  114.93
# 151         coahuayana      MX  18.62 -100.35
# 166           brainerd      US  46.36  -94.20
# 167              yumen      CN  40.29   97.04
# ...

# %%
base_url ="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params ={"type": "hotel",
            "keyword": "hotel",
            "radius": 5000,
            "key": g_key}

# %%
for index, row in hotel_df.iterrows():    
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    params["location"]= f"{lat},{lng}"
    
    
    #assemble url and make API requests
    print(f"Retrieve Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    results = response['results']
    
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result...skipping")
    print("-------")
    
    #time.sleep(1)
    
print("-------End of Search-------")
# Out:
# Retrieve Results for Index 3: zhuhai.
# Missing field/result...skipping
# -------
# Retrieve Results for Index 7: opuwo.
# Closest hotel in opuwo is Opuwo Country Lodge.
# -------
# Retrieve Results for Index 9: pushkinskiye gory.
# Closest hotel in pushkinskiye gory is Baza Otdykha "Zaozer'ye".
# -------
# Retrieve Results for Index 11: castro.
# Closest hotel in castro is Enjoy Chiloé. Hotel De La Isla.
# -------
# Retrieve Results for Index 26: colonelganj.
# Closest hotel in colonelganj is Bangil Setor.
# -------
# Retrieve Results for Index 30: gobabis.
# Closest hotel in gobabis is Goba Lodge.
# -------
# Retrieve Results for Index 31: qingdao.
# Closest hotel in qingdao is InterContinental Qingdao.
# -------
# Retrieve Results for Index 33: arman.
# Missing field/result...skipping
# -------
# Retrieve Results for Index 37: varhaug.
# Closest hotel in varhaug is Huset ved havet.
# -------
# Retrieve Results for Index 50: kodiak.
# Missing field/result...skipping
# -------
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

#Add the layer to the map
fig.add_layer(markers)

# Display figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
